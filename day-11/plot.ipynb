# %% [markdown]
# # Plotting in python:
# by Yunus Teli

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Smart\AppData\Local\Temp\ipykernel_19956\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# import dataset
kashti = sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot( x='survived',hue='sex', data= kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# scatter plot
plt.scatter(data=kashti, x= 'age', y='fare')

# %%
plt.scatter(data=kashti, x='age', y='fare', hue='pclass')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.scatter(data=kashti, x='age', y='fare', hue='pclass')
#
# File c:\Users\Smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
#    3706         norm=norm,
#    3707         vmin=vmin,
#    3708         vmax=vmax,
#    3709         alpha=alpha,
#    3710         linewidths=linewidths,
# ...

# %%
sns.scatterplot(data=kashti, x='age', y='fare', hue='pclass')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=kashti, x='sex', y='fare', hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(data=kashti, x='sex', y='fare', hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(kashti)

# %%
kashti.hist(bins= 10, figsize= (9,7),grid= False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.boxplot(data=kashti, x='sex', y='fare', hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti, x='sex', y='fare', hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#  Assignment: how to change the x and y axis titles

# %%
g= sns.FacetGrid(kashti,hue="survived",col="pclass",margin_titles=True,
              palette={1:"seagreen",0:"grey"})
g=g.map(plt.scatter,"fare","age",edgecolor= "w").add_legend();

# %%
g= sns.FacetGrid(kashti,hue="survived",col="sex",margin_titles=True,
              palette={1:"seagreen",0:"grey"})
g=g.map(plt.scatter,"fare","age",edgecolor= "w").add_legend();

# %%
g= sns.FacetGrid(kashti,hue="survived",col="sex",margin_titles=True,
              palette={1:"seagreen",0:"grey"})
g=g.map(plt.scatter,"fare","age",edgecolor= "w").add_legend();

# %%
sns.stripplot(data=kashti, x='sex', y='fare', hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# heat map
corr = kashti.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 # heat map
# ----> 2 corr = kashti.corr()
#       3 plt.figure(figsize=(10,10))
#       4 sns.heatmap(corr)
#
# File c:\Users\Smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exclude non-numeric columns
numeric_columns = kashti.select_dtypes(include=['number'])
corr = numeric_columns.corr()

# Plot the heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr)
plt.title('Correlation Heatmap')
plt.show()
